# %% [markdown]
# # 🪄 abcli notebook

# %%
import os
os.environ["abcli_path_bash"] = "{}/git/awesome-bash-cli/bash".format(os.getenv("HOME"))

# %%
from blue_options import fullname, string
from blue_objects import objects

from notebooks_and_scripts import NAME, VERSION
from notebooks_and_scripts.logger import logger

logger.info(f"{NAME}-{VERSION}.{fullname()}, built on {string.pretty_date()}")
# Out:
# 📜  notebooks_and_scripts-4.725.1.blue_options-4.76.1, built on 25 September 2024, 20:49:15

# %%
object_name = f"fascinating-magic-{string.timestamp()}"
object_path = objects.object_path(object_name)

# %% [markdown]
# ---

# %%
logger.info("Hello World! 🪄")
# Out:
# 📜  Hello World! 🪄

# %% [markdown]
# ---

# %%
# END
