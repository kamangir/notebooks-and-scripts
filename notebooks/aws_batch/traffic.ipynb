# %% [markdown]
# # networkx

# %%
import os
os.environ["abcli_path_bash"] = "{}/git/awesome-bash-cli/bash".format(os.getenv("HOME"))

# %%
# !pip3 install networkx matplotlib
# !pip3 install pydot

# %%
from abcli import fullname
from abcli import string
from abcli import file
from abcli.modules import objects
from notebooks_and_scripts import NAME, VERSION
from notebooks_and_scripts.logger import logger
from notebooks_and_scripts.workflow.patterns import load_pattern, list_of_patterns

logger.info(f"{NAME}-{VERSION}-{fullname()}, built on {string.pretty_date()}")
# Out:
# 📜  notebooks_and_scripts-4.365.1-abcli-8.126.1, built on 01 May 2024, 19:02:46

# %% [markdown]
# ---

# %%
object_name = f"traffic-{string.timestamp()}"
object_path = objects.object_path(object_name)

# %%
logger.info("{} pattern(s): {}".format(
    len(list_of_patterns()),
    ",".join(list_of_patterns()),
))
# Out:
# 📜  2 pattern(s): hourglass,a-bc-d

# %%
#pattern = "a-bc-d"
pattern = "hourglass"

# %%
success, graph = load_pattern(
    pattern=pattern,
    export_as_image=os.path.join(object_path,f"{pattern}.png"),
)
assert success
# Out:
# 📜  loaded MultiDiGraph named 'G' with 25 nodes and 24 edges from /Users/kamangir/git/notebooks-and-scripts/notebooks_and_scripts/workflow/patterns/hourglass.dot.
# :: figure -> /Users/kamangir/storage/abcli/traffic-2024-05-01-19-02-46-74003/hourglass.png

# %% [markdown]
# ---

# %%
# %%bash -s $object_name
# source ~/git/awesome-bash-cli/bash/abcli.sh in_notebook
#
# object_name=$1
#
# abcli upload - $object_name
# Out:
# 📜 awesome-bash-cli: .env: 22 env var(s)
# 📜 awesome-bash-cli: abcli/config.env: 13 env var(s)
# 🔋 gpu: not found.
# 🚀 abcli-8.126.1.current
# confirmed: traffic-2024-05-01-19-02-46-74003 does not exist.
# traffic-2024-05-01-19-02-46-74003 open upload started.
# upload: ../../../../storage/abcli/traffic-2024-05-01-19-02-46-74003/hourglass.png to s3://kamangir/bolt/traffic-2024-05-01-19-02-46-74003/hourglass.png
# :: traffic-2024-05-01-19-02-46-74003 += #open.

# %%
# END
