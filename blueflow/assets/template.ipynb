# %% [markdown]
# # 🌀 blueflow notebook

# %%
from blueflow import notebooks

from blue_options import fullname, string
from blue_objects import mlflow, objects

from blueflow import NAME, VERSION
from blueflow.logger import logger

logger.info(f"{NAME}-{VERSION}.{fullname()}, built on {string.pretty_date()}")
# Out:
# 📜  blueflow-4.794.1.blue_options-4.157.1, built on 21 November 2024, 18:20:12

# %%
object_name = objects.unique_object("fascinating-magic")
object_path = objects.object_path(object_name)
# Out:
# 🌀  📂 fascinating-magic-2024-11-21-18-20-12-16989

# %% [markdown]
# ---

# %%
logger.info("Hello World! 🪄")
# Out:
# 📜  Hello World! 🪄

# %% [markdown]
# ---

# %%
assert objects.upload(object_name)
assert mlflow.log_run(object_name)
# Out:
# 🌀  ⏺️  fascinating-magic-2024-11-21-18-20-12-16989 | 00001
# 🏃 View run fascinating-magic-2024-11-21-18-20-12-16989-00001 at: https://dbc-3ac1d106-bf0c.cloud.databricks.com/ml/experiments/336459975123094/runs/2d0ecf0088284427b6577691ccfda947
# 🧪 View experiment at: https://dbc-3ac1d106-bf0c.cloud.databricks.com/ml/experiments/336459975123094
# 🌀  ⏹️  fascinating-magic-2024-11-21-18-20-12-16989

# %%
# END
